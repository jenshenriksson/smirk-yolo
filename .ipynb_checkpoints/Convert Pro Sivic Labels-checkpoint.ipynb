# %% [markdown]
# ## Converting from CSV file to Yolo format:
#
# MainType
# -    Run1
#     - cam000001.txt
#     - cam000002.txt
#     - ...
# -    Run2
#     - ...

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 

import os 

label_file = './labels/labels_bfm.csv'

# %%
df = pd.read_csv(label_file)

# %%
ctr = 0 
for index, row in df.iterrows():
    parts = row['file'].replace('\\','/').split('/')
    path = ''
    for part in parts:
        path = os.path.join(path, part)
        if not os.path.isdir(path) and not path.endswith('.png'):
            os.mkdir(path)
    # Extract BB information
    bounding_box = row.loc[(['x_min','x_max','y_min','y_max'])]
    xmin, xmax, ymin, ymax = bounding_box.values
    width, height = row['image_width'], row['image_height']    
    
    # Write the label file 
    label_path = path.replace('.png', '.txt')
    
    # if os.path.exists(label_path):  # file exists! Append new object
    file_object = open(label_path, 'a')
    
    # Check if they're NaN --> Take next if true. 
    if bounding_box.isnull().values.any(): 
        file_object.close()
        continue 
    else:
        # YOLO formating: 
        yolo_x_centre = ((xmin+xmax)/2) / width
        yolo_y_centre = ((ymin+ymax)/2) / height
        yolo_width = (xmax-xmin) / width
        yolo_height = (ymax-ymin) / height
        
        file_object.write(' '.join([str(x) for x in [0, yolo_x_centre, yolo_y_centre, yolo_width, yolo_height]]))
        file_object.close()
    
    # For status updates: Print a progress bar 
    ctr += 1
    if ctr%500==0:
        print('Done {} of {}'.format(ctr, len(df)), end='\r', flush=True)
# Out:
# Done 67000 of 69095

# %% [markdown]
# ## Select a subset as training, testing and validation data

# %%
'abc'.replace('b','d')
# Out:
# 'adc'

# %%
d = {}
for index, row in df.iterrows():
    parts = row['file'].replace('\\','/').split('/')
    for part in parts: 
        if part in d.keys(): 
            d[part] = d[part] + 1
        else :
            d[part] = 1

# %%
df
# Out:
#        Unnamed: 0                                             file  \
# 0               0  male_casual\iCg8fMTLyEahuVnQ0Hp2C\cam000001.png
# 1               1  male_casual\iCg8fMTLyEahuVnQ0Hp2C\cam000002.png
# 2               2  male_casual\iCg8fMTLyEahuVnQ0Hp2C\cam000003.png
# 3               3  male_casual\iCg8fMTLyEahuVnQ0Hp2C\cam000004.png
# 4               4  male_casual\iCg8fMTLyEahuVnQ0Hp2C\cam000005.png
# ...           ...                                              ...
# 56230       56230  male_casual\cHi6iC8f5BKJZnQkOE1LW\cam000221.png
# 56231       56231  male_casual\cHi6iC8f5BKJZnQkOE1LW\cam000222.png
# 56232       56232  male_casual\cHi6iC8f5BKJZnQkOE1LW\cam000223.png
# 56233       56233  male_casual\cHi6iC8f5BKJZnQkOE1LW\cam000224.png
# 56234       56234  male_casual\cHi6iC8f5BKJZnQkOE1LW\cam000225.png
#
#        image_width  image_height  x_min  x_max  y_min  y_max  class_text  \
# 0              752           480    NaN    NaN    NaN    NaN  background
# 1              752           480    NaN    NaN    NaN    NaN  background
# 2              752           480    NaN    NaN    NaN    NaN  background
# 3              752           480    NaN    NaN    NaN    NaN  background
# 4              752           480    NaN    NaN    NaN    NaN  background
# ...            ...           ...    ...    ...    ...    ...         ...
# 56230          752           480  152.0  193.0  203.0  318.0  pedestrian
# 56231          752           480  142.0  203.0  196.0  290.0  pedestrian
# 56232          752           480  115.0  203.0  187.0  280.0  pedestrian
# 56233          752           480  109.0  191.0  193.0  300.0  pedestrian
# 56234          752           480  115.0  169.0  198.0  334.0  pedestrian
#
#        class_label                 run_id  object_type  \
# 0                0  iCg8fMTLyEahuVnQ0Hp2C  male_casual
# 1                0  iCg8fMTLyEahuVnQ0Hp2C  male_casual
# 2                0  iCg8fMTLyEahuVnQ0Hp2C  male_casual
# 3                0  iCg8fMTLyEahuVnQ0Hp2C  male_casual
# 4                0  iCg8fMTLyEahuVnQ0Hp2C  male_casual
# ...            ...                    ...          ...
# 56230            1  cHi6iC8f5BKJZnQkOE1LW  male_casual
# 56231            1  cHi6iC8f5BKJZnQkOE1LW  male_casual
# 56232            1  cHi6iC8f5BKJZnQkOE1LW  male_casual
# 56233            1  cHi6iC8f5BKJZnQkOE1LW  male_casual
# 56234            1  cHi6iC8f5BKJZnQkOE1LW  male_casual
#
#        start_distance_from_car  angle  speed  offset_from_road_center  \
# 0                           10   30.0      1                      NaN
# 1                           10   30.0      1                      NaN
# 2                           10   30.0      1                      NaN
# 3                           10   30.0      1                      NaN
# 4                           10   30.0      1                      NaN
# ...                        ...    ...    ...                      ...
# 56230                      100    NaN      4                      3.0
# 56231                      100    NaN      4                      3.0
# 56232                      100    NaN      4                      3.0
# 56233                      100    NaN      4                      3.0
# 56234                      100    NaN      4                      3.0
#
#       scenario_type
# 0              left
# 1              left
# 2              left
# 3              left
# 4              left
# ...             ...
# 56230       towards
# 56231       towards
# 56232       towards
# 56233       towards
# 56234       towards
#
# [56235 rows x 17 columns]

# %%
'%5d'% (1)
# Out:
# '    1'
