# %% [markdown]
# ## Converting from CSV file to Yolo format:
# Data is in .csv format where each row describes an object in a scene. In this scenario, no sequence information is utilized, hence the data can be converted directly to the yolo format, where each training image has a corresponding label file. The labels are automatically found by replacing "image" with the word labels. Hence the format we are looking for looks like the following:
#
# Training set
# * Images
#     + P3_Female_casual
#         + Random Identifier 1
#             + cam000001.png
#             + cam000002.png
#
#         + Random Identifier 2
#             + ...
#
#     + ...
#
# * Labels
#     + P3_Female_casual
#         + Random Identifier 1
#             + cam000001.txt
#             + cam000002.txt
#
#         + Random Identifier 2
#             + ...
#
#     + ...
#
#
# The images are provided in this format, but the labels are not. Below we are converting the .csv file to a .txt file per image.

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import os

# %%
# Location of label.csv file 

# INLIERS
# label_file = './label_files/male_casual_labels.csv'
# label_file = './label_files/female_business_casual_labels.csv'
# label_file = './label_files/male_business_labels.csv'



# OUTLIERS 
label_file = './label_files/outlier_cylinder.csv'



# Read in data, and print example's 

df = pd.read_csv(label_file)
df.head()

path = 'labels'
if not os.path.isdir(path):
    os.mkdir(path)

# %%
ctr = 0 
for index, row in df.iterrows():
    parts = row['file'].replace('\\','/').split('/')
    path = 'labels'
    for part in parts:
        path = os.path.join(path, part)
        if not os.path.isdir(path) and not path.endswith('.png'):
            os.mkdir(path)
    # Extract BB information
    bounding_box = row.loc[(['x_min','x_max','y_min','y_max'])]
    xmin, xmax, ymin, ymax = bounding_box.values
    width, height = row['image_width'], row['image_height']    
    
    # Write the label file 
    label_path = path.replace('.png', '.txt')
    
    # if os.path.exists(label_path):  # file exists! Append new object
    file_object = open(label_path, 'a')
    
    # Check if they're NaN --> Take next if true. 
    if bounding_box.isnull().values.any(): 
        file_object.close()
        continue 
    else:
        # YOLO formating: 
        if row['class_text'] == 'pedestrian':
            yolo_x_centre = ((xmin+xmax)/2) / width
            yolo_y_centre = ((ymin+ymax)/2) / height
            yolo_width = (xmax-xmin) / width
            yolo_height = (ymax-ymin) / height

            file_object.write(' '.join([str(x) for x in [0, yolo_x_centre, yolo_y_centre, yolo_width, yolo_height]]))
    file_object.close()
    
    # For status updates: Print a progress bar 
    ctr += 1
    if ctr%500==0:
        print('Done {} of {}'.format(ctr, len(df)), end='\r', flush=True)

# %% [markdown]
# **Repeat read in step and conversion step for every label file.**

# %%
df.head()
# Out:
#                                   file  frame_index  image_width  \
# 0  xnK0WHGQmGFHGgs7yphZD/cam000001.png            1          752
# 1  xnK0WHGQmGFHGgs7yphZD/cam000002.png            2          752
# 2  xnK0WHGQmGFHGgs7yphZD/cam000003.png            3          752
# 3  xnK0WHGQmGFHGgs7yphZD/cam000004.png            4          752
# 4  xnK0WHGQmGFHGgs7yphZD/cam000005.png            5          752
#
#    image_height  x_min  x_max  y_min  y_max  is_occluded  current_distance  \
# 0           480  132.0  181.0  223.0  340.0        False             10.84
# 1           480  123.0  190.0  230.0  324.0        False             11.22
# 2           480  126.0  211.0  237.0  312.0        False             11.61
# 3           480  139.0  211.0  230.0  311.0        False             11.99
# 4           480  163.0  206.0  219.0  319.0        False             12.38
#
#    class_text                 run_id scenario_type    object_type  \
# 0  pedestrian  xnK0WHGQmGFHGgs7yphZD          away  male_business
# 1  pedestrian  xnK0WHGQmGFHGgs7yphZD          away  male_business
# 2  pedestrian  xnK0WHGQmGFHGgs7yphZD          away  male_business
# 3  pedestrian  xnK0WHGQmGFHGgs7yphZD          away  male_business
# 4  pedestrian  xnK0WHGQmGFHGgs7yphZD          away  male_business
#
#    start_distance_from_car  speed  angle  offset_from_road_center
# 0                       10      4    NaN                      3.0
# 1                       10      4    NaN                      3.0
# 2                       10      4    NaN                      3.0
# 3                       10      4    NaN                      3.0
# 4                       10      4    NaN                      3.0
